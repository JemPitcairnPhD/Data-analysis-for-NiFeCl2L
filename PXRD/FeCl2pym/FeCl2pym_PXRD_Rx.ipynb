# %%
##these just load the required libaries
# %matplotlib notebook
import matplotlib.pyplot as plt 
import matplotlib
import numpy as np
from cycler import cycler

# %%
data = np.loadtxt('FeCl2pym_PXRD_xeroji_riet_01.dat') #PXRD data file which has been converted to .dat or .xy
rug = np.genfromtxt('FeCl2pym_PXRD_xeroji_riet_01_rug_marks.dat')

# %%
fig = plt.figure(100, figsize=(5.3, 2.5))
ax1 = plt.subplot()
ax1.tick_params(axis='both', labelsize=8, direction="in")

Q = 4*np.pi*np.sin(data[:,0]/2/180*np.pi)/1.54

obs = ax1.scatter (Q,data[:,1], s=3, label='$I_{obs}$', color='black')
calc, = ax1.plot (Q,data[:,2], linewidth=1.5, label='$I_{calc}$', color='tomato')
diff, = ax1.plot (Q,data[:,3]+70, linewidth=1.5, label='$I_{obs}$-$I_{calc}$', color='lightgrey')
plt.fill_between(Q, (data[:,1] - data[:,4]), (data[:,1] + data[:,4]), color='lightcoral', alpha=0.2)
np.argmax(rug>3)
ax1.plot(rug[:,4], ([180]*len(rug)), '|', ms=7, c='tomato')

ax1.set_xlabel('$Q$ (Å$^{-1}$)', fontsize=9)
ax1.set_ylabel('$I$', fontsize=9)
ax1.set_xlim((0.28,4.6))
plt.yticks([])
plt.xticks(fontsize=8)
ax1.tick_params(axis='both', labelsize=8)
ax1.legend([obs, calc, diff],['$I_{\mathrm{obs\;(ambient)}}$','$I_{\mathrm{calc}}$','$I_{\mathrm{obs}}-I_{\mathrm{calc}}$'], frameon=False, loc='upper right', fontsize=7)
plt.tight_layout()
#plt.savefig('FeCl2pym_PXRD_xeroji_riet.pdf', bbox_inches='tight', transparent=True) #The output of your plot as an image or a pdf
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="530">
